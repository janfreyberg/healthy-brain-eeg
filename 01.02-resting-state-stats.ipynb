# %%
library(tidyverse)
library(stringr)
library(tidyr)
library(broom)
library(corrr)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %% [markdown]
# Read the data into a tibble

# %%
data <- read_csv('data/interim/csv/metrics-pheno.csv')

data <- data %>%
  gather(type, value, semilogintercepts, semilogslopes)
# Out:
# Parsed with column specification:
# cols(
#   pid = col_character(),
#   semilogintercepts = col_double(),
#   semilogslopes = col_double(),
#   Sex = col_integer(),
#   Age = col_double(),
#   EHQ_Total = col_double(),
#   Study_Site = col_integer(),
#   Commercial_Use = col_character()
# )

# %%
ggplot(data, aes(x=Age, y=value)) +
  facet_wrap(~type, scales='free') +
  geom_point()
# Out:
# plot without title
